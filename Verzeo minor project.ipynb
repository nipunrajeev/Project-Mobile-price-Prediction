# %% [markdown]
# # Data Import

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('mobile_price_range_data.csv')

# %%
data
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# # Data Analysis and cleaning

# %%
data.shape
# Out:
# (2000, 21)

# %% [markdown]
# ### Checking for null values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# ### Ploting datas to analyse the trends

# %%
data.plot(x='price_range',y='ram',kind='scatter')
plt.show()

# %%
data.plot(x='price_range',y='battery_power',kind='scatter')
plt.show()

# %%
data.plot(x='price_range',y='fc',kind='scatter')
plt.show()

# %%
data.plot(kind='box',figsize=(25,15))
plt.show()

# %% [markdown]
# # Spliting into Train and Test set

# %%
X=data.drop('price_range',axis=1)
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
Y=data['price_range']
Y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1194           1299     0          2.8         1   2       0          60
# 45             1514     0          2.9         0   0       0          27
# 1477           1150     1          2.7         0   0       0          39
# 1293           1702     0          1.0         0   7       0          36
# 1736           1779     1          2.6         1   2       0           5
# ...             ...   ...          ...       ...  ..     ...         ...
# 1791           1203     1          0.5         1   0       1          11
# 1096           1154     0          2.0         0   6       1          35
# 1932            718     1          1.6         1   1       1          30
# 235            1523     1          1.8         0   6       1          11
# 1061           1522     1          0.7         1   4       0          28
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
Y_train
# Out:
# 1194    1
# 45      1
# 1477    0
# 1293    2
# 1736    1
#        ..
# 1791    0
# 1096    3
# 1932    1
# 235     0
# 1061    1
# Name: price_range, Length: 1400, dtype: int64

# %% [markdown]
# ### Now we have split the data into train and test set where train set contains 1400 data and test 600 data.We first run models on x_train and y_train then make the model to predict price for x_test and then compare it with y_test to find the accuracy....

# %% [markdown]
# # 1) Logistic Regression

# %%
#### using Standard Scaler ...

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()

X_train_std=std.fit_transform(X_train)

X_test_std=std.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train_std,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=lr.predict(X_test_std)

Y_pred
# Out:
# array([0, 0, 1, 1, 3, 2, 0, 2, 2, 3, 0, 3, 1, 1, 3, 0, 0, 1, 1, 1, 3, 3,
#        1, 2, 3, 2, 2, 3, 2, 2, 2, 1, 2, 0, 3, 3, 0, 0, 0, 0, 2, 1, 2, 1,
#        0, 1, 2, 2, 1, 2, 1, 3, 1, 3, 1, 3, 1, 2, 3, 1, 0, 2, 0, 3, 2, 1,
#        1, 2, 3, 2, 1, 1, 0, 3, 3, 1, 2, 1, 0, 0, 0, 3, 1, 2, 3, 2, 2, 0,
#        1, 1, 3, 0, 1, 1, 2, 3, 3, 0, 3, 3, 3, 3, 0, 1, 2, 0, 0, 1, 0, 2,
#        0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 2, 0, 0, 0, 3, 0, 1, 1, 0, 1, 0, 2,
#        0, 3, 3, 0, 3, 2, 2, 1, 0, 0, 3, 1, 0, 2, 0, 0, 0, 1, 3, 3, 2, 1,
#        0, 2, 1, 0, 3, 1, 3, 1, 2, 2, 3, 1, 2, 2, 3, 2, 2, 0, 2, 2, 0, 3,
#        3, 0, 0, 3, 0, 3, 0, 0, 2, 3, 3, 1, 2, 1, 2, 3, 2, 2, 0, 1, 2, 3,
#        3, 1, 3, 2, 0, 1, 2, 2, 2, 1, 0, 2, 0, 3, 2, 0, 2, 0, 1, 0, 2, 1,
#        0, 1, 2, 1, 3, 3, 0, 3, 2, 1, 0, 2, 3, 3, 2, 1, 0, 1, 3, 2, 3, 2,
#        1, 1, 0, 1, 3, 0, 3, 3, 3, 1, 2, 1, 0, 1, 1, 3, 2, 0, 3, 1, 1, 1,
#        2, 1, 2, 0, 3, 2, 2, 0, 0, 1, 3, 3, 0, 1, 1, 2, 3, 2, 1, 2, 2, 0,
# ...

# %%
from sklearn.metrics import accuracy_score
lr_ac=accuracy_score(Y_test,Y_pred)

lr_ac
# Out:
# 0.935

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_pred,Y_test)
# Out:
# array([[133,   6,   0,   0],
#        [  2, 137,   8,   0],
#        [  0,   6, 150,   7],
#        [  0,   0,  10, 141]])

# %% [markdown]
# # 2) KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train_std,Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred=knn.predict(X_test_std)
Y_pred
# Out:
# array([0, 1, 1, 0, 1, 1, 0, 2, 1, 3, 0, 3, 2, 0, 2, 0, 1, 1, 1, 2, 1, 2,
#        1, 3, 3, 2, 2, 1, 1, 3, 1, 1, 2, 0, 3, 1, 0, 0, 1, 1, 0, 1, 2, 0,
#        0, 0, 1, 2, 0, 2, 0, 1, 0, 2, 1, 3, 0, 2, 2, 0, 0, 3, 0, 2, 0, 2,
#        1, 2, 3, 2, 1, 3, 0, 3, 2, 1, 3, 0, 1, 0, 0, 3, 0, 1, 3, 2, 2, 0,
#        2, 0, 1, 0, 0, 1, 0, 2, 2, 0, 1, 1, 2, 3, 0, 0, 2, 0, 0, 1, 1, 0,
#        0, 3, 2, 1, 1, 0, 1, 0, 1, 1, 1, 0, 0, 0, 3, 1, 1, 0, 1, 1, 0, 2,
#        0, 2, 2, 1, 2, 2, 1, 2, 1, 1, 3, 0, 0, 2, 0, 1, 0, 0, 2, 3, 1, 1,
#        0, 0, 1, 0, 2, 1, 2, 0, 2, 2, 3, 0, 3, 2, 3, 1, 1, 0, 1, 0, 1, 3,
#        2, 0, 0, 3, 0, 3, 0, 2, 1, 3, 3, 1, 1, 1, 2, 1, 2, 3, 0, 2, 1, 3,
#        2, 0, 3, 2, 0, 3, 2, 0, 1, 0, 0, 1, 1, 2, 2, 0, 1, 0, 1, 0, 3, 1,
#        2, 2, 2, 2, 2, 1, 0, 3, 2, 1, 0, 1, 3, 3, 1, 1, 0, 1, 2, 0, 3, 2,
#        0, 1, 0, 2, 1, 0, 2, 2, 2, 0, 0, 1, 1, 1, 1, 2, 1, 0, 1, 0, 1, 2,
#        2, 2, 2, 0, 1, 0, 3, 0, 1, 2, 2, 3, 0, 1, 1, 2, 3, 1, 1, 0, 2, 1,
# ...

# %%
knn_ac=accuracy_score(Y_test,Y_pred)
knn_ac
# Out:
# 0.48833333333333334

# %%
confusion_matrix(Y_pred,Y_test)
# Out:
# array([[98, 58, 23,  0],
#        [33, 60, 57, 26],
#        [ 4, 27, 60, 47],
#        [ 0,  4, 28, 75]])

# %% [markdown]
# # SVM Classifier with linear and rbf kernel

# %%
from sklearn.svm import SVC
linear=SVC(kernel="linear")
linear.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
Y_pred = linear.predict(X_test)
Y_pred
# Out:
# array([0, 0, 1, 1, 2, 2, 0, 2, 2, 3, 0, 3, 1, 1, 3, 0, 0, 1, 1, 1, 3, 3,
#        1, 2, 3, 2, 2, 3, 2, 2, 2, 1, 2, 0, 3, 3, 0, 0, 0, 1, 2, 1, 2, 1,
#        0, 1, 2, 2, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 1, 0, 2, 1, 3, 2, 1,
#        1, 2, 3, 2, 1, 2, 0, 3, 3, 1, 2, 1, 0, 0, 0, 3, 1, 2, 3, 2, 2, 0,
#        1, 1, 3, 0, 1, 1, 2, 3, 3, 0, 3, 3, 3, 3, 0, 1, 2, 0, 0, 1, 0, 2,
#        0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 1, 0, 0, 0, 3, 0, 1, 1, 0, 1, 0, 2,
#        0, 3, 3, 0, 3, 2, 2, 1, 0, 0, 3, 1, 0, 2, 0, 0, 0, 1, 3, 3, 1, 1,
#        0, 1, 1, 0, 3, 2, 3, 1, 2, 2, 3, 1, 2, 2, 3, 2, 2, 0, 2, 2, 0, 3,
#        3, 0, 0, 3, 0, 3, 0, 0, 2, 3, 3, 1, 2, 1, 2, 3, 2, 2, 0, 1, 1, 3,
#        3, 1, 3, 2, 0, 1, 2, 2, 1, 1, 0, 2, 0, 3, 2, 0, 3, 0, 1, 0, 2, 1,
#        0, 1, 2, 2, 3, 3, 0, 3, 2, 1, 0, 2, 3, 3, 2, 1, 0, 1, 3, 2, 3, 2,
#        2, 2, 0, 1, 3, 0, 3, 3, 3, 1, 2, 2, 0, 1, 1, 3, 2, 0, 3, 1, 1, 1,
#        2, 1, 2, 0, 3, 2, 2, 0, 0, 1, 3, 3, 0, 1, 1, 2, 3, 2, 2, 2, 2, 0,
# ...

# %%
linear_ac=accuracy_score(Y_test, Y_pred)
linear_ac
# Out:
# 0.965

# %%
confusion_matrix(Y_pred,Y_test)
# Out:
# array([[133,   2,   0,   0],
#        [  2, 144,   6,   0],
#        [  0,   3, 157,   3],
#        [  0,   0,   5, 145]])

# %%
rbf=SVC(kernel="rbf")
rbf.fit(X_train,Y_train)
Y_pred = rbf.predict(X_test)
Y_pred
# Out:
# array([0, 0, 1, 0, 3, 2, 0, 2, 2, 3, 0, 3, 1, 1, 3, 0, 0, 1, 1, 1, 3, 3,
#        1, 2, 3, 2, 2, 3, 2, 2, 2, 1, 2, 0, 3, 3, 0, 0, 0, 1, 1, 1, 2, 1,
#        0, 1, 2, 2, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 1, 0, 2, 1, 3, 2, 1,
#        0, 2, 3, 2, 1, 1, 0, 3, 3, 1, 2, 1, 0, 0, 0, 3, 1, 2, 3, 2, 2, 0,
#        1, 1, 3, 0, 1, 1, 2, 3, 3, 0, 2, 3, 3, 3, 0, 1, 2, 0, 0, 1, 0, 2,
#        0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 2, 0, 0, 0, 3, 0, 1, 1, 0, 1, 0, 3,
#        0, 3, 3, 0, 3, 2, 2, 1, 0, 0, 3, 1, 0, 2, 0, 0, 0, 1, 3, 3, 1, 1,
#        0, 2, 1, 0, 3, 1, 3, 1, 3, 2, 3, 1, 2, 1, 3, 2, 2, 0, 2, 2, 0, 3,
#        3, 0, 0, 3, 0, 3, 0, 0, 2, 3, 3, 1, 2, 1, 2, 3, 2, 3, 0, 1, 2, 3,
#        3, 1, 3, 2, 0, 1, 2, 2, 2, 1, 1, 2, 0, 2, 2, 0, 2, 0, 1, 0, 2, 1,
#        0, 1, 2, 1, 3, 3, 0, 3, 2, 1, 0, 2, 3, 3, 2, 1, 0, 1, 3, 2, 3, 2,
#        2, 1, 0, 1, 2, 0, 3, 3, 3, 1, 2, 1, 0, 1, 1, 3, 2, 0, 3, 1, 1, 1,
#        2, 1, 2, 0, 3, 2, 2, 0, 0, 1, 3, 3, 0, 1, 1, 2, 3, 2, 2, 2, 2, 0,
# ...

# %%
rbf_ac=accuracy_score(Y_test, Y_pred)
rbf_ac
# Out:
# 0.9433333333333334

# %%
confusion_matrix(Y_pred,Y_test)
# Out:
# array([[134,   7,   0,   0],
#        [  1, 138,  10,   0],
#        [  0,   4, 151,   5],
#        [  0,   0,   7, 143]])

# %% [markdown]
# # Classification report for Models.

# %%
plt.bar(x=['knn','lr','linear','rbf'],height=[knn_ac,lr_ac,linear_ac,rbf_ac])
plt.xlabel("Algorithms")
plt.ylabel("Accuracy Score")
plt.show()

# %% [markdown]
# ### From here we understand that best model for our data set is SVM Classifier with linear kernel

# %%
linear.predict(X_test)
# Out:
# array([0, 0, 1, 1, 2, 2, 0, 2, 2, 3, 0, 3, 1, 1, 3, 0, 0, 1, 1, 1, 3, 3,
#        1, 2, 3, 2, 2, 3, 2, 2, 2, 1, 2, 0, 3, 3, 0, 0, 0, 1, 2, 1, 2, 1,
#        0, 1, 2, 2, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 3, 1, 0, 2, 1, 3, 2, 1,
#        1, 2, 3, 2, 1, 2, 0, 3, 3, 1, 2, 1, 0, 0, 0, 3, 1, 2, 3, 2, 2, 0,
#        1, 1, 3, 0, 1, 1, 2, 3, 3, 0, 3, 3, 3, 3, 0, 1, 2, 0, 0, 1, 0, 2,
#        0, 3, 1, 1, 2, 2, 3, 1, 2, 1, 1, 0, 0, 0, 3, 0, 1, 1, 0, 1, 0, 2,
#        0, 3, 3, 0, 3, 2, 2, 1, 0, 0, 3, 1, 0, 2, 0, 0, 0, 1, 3, 3, 1, 1,
#        0, 1, 1, 0, 3, 2, 3, 1, 2, 2, 3, 1, 2, 2, 3, 2, 2, 0, 2, 2, 0, 3,
#        3, 0, 0, 3, 0, 3, 0, 0, 2, 3, 3, 1, 2, 1, 2, 3, 2, 2, 0, 1, 1, 3,
#        3, 1, 3, 2, 0, 1, 2, 2, 1, 1, 0, 2, 0, 3, 2, 0, 3, 0, 1, 0, 2, 1,
#        0, 1, 2, 2, 3, 3, 0, 3, 2, 1, 0, 2, 3, 3, 2, 1, 0, 1, 3, 2, 3, 2,
#        2, 2, 0, 1, 3, 0, 3, 3, 3, 1, 2, 2, 0, 1, 1, 3, 2, 0, 3, 1, 1, 1,
#        2, 1, 2, 0, 3, 2, 2, 0, 0, 1, 3, 3, 0, 1, 1, 2, 3, 2, 2, 2, 2, 0,
# ...

# %%
### accuracy for linear svm is 96.5%
linear_ac
# Out:
# 0.965
